# %%
import pytesseract
from PIL import Image
import pyttsx3

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\VANSH GUPTA\AppData\Local\Tesseract-OCR\tesseract.exe"

# %%
img = Image.open("2.PNG").convert('LA')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)

# %%
#text = text.replace("\n"," ")
print(text)
# Out:
# I am an efficient college student (8.0 GPA, Btech in ECE) currently attending Guru Gobind Singh
#
# Indraprastha University. During the course of my academic career, I also managed to accrue
#
#
#
# nearly 6 months of work experience. I had the privilege of working for Data-Stats in a machine
# learning intern role in my free time, where I learned valuable professional skills such as research
# and development, process development and methods design. In both my academic and
# professional life, I have been consistently praised as quality-oriented by my professors and peers.
# Whether working on academic, extracurricular, or professional projects, I apply proven
# leadership, teamwork and problem-solving skills, which I hope to leverage into the Data Science
#
# Intern role at your company.

# %%
engine = pyttsx3.init()
engine.say(text)
engine.runAndWait()
engine.stop()
